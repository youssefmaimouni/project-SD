# %%
from pymongo import MongoClient

# Replace with your MongoDB connection string
uri = "mongodb+srv://team_member:projectSD_Media1@cluster0.m6cwo.mongodb.net/projectSD?retryWrites=true&w=majority"


# Connect to MongoDB
client = MongoClient(uri)

# Select the database and collection
db = client["projectSD"]  # Replace with your database name
collection = db["france24"]  # Replace with your collection name

# Fetch and print all documents
documents = collection.find()

for doc in documents:
    print(doc)  # Print each document

# Close the connection
client.close()
# Out:
# {'_id': ObjectId('67bb48c33401a86a45276ed7'), 'Unnamed: 0': 0, 'source': 'France 24', 'title': 'الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النهائي والجزائر تستنكر الدعاية "الباطلة" ضدها', 'content': '\r\nوسط تواصل الجدل بشأنها واستنكار الجزائر الدعاية "الباطلة" بحقها، لم ينتهِ النزال بين الملاكمة الجزائرية إيمان خليف وخصمتها أنجيلا كاريني بشكل طبيعي الخميس في أولمبياد باريس، إذ انسحبت الإيطالية بعد 46 ثانية إثر لكمتين قويتين على رأسها من خليف.\r\nوتأهلت الجزائرية إلى الدور ربع النهائي من وزن 66 كلغ، بعد رفض كاريني متابعة النزال، ورفضت أيضا مصافحة خصمتها بعد إعلان فوزها.\r\nجثت كاريني على ركبتيها باكية، فيما قال مدرب إيطالي إنها تعرضت لضربة قوية على أنفها. أعلن القرار الرسمي خسارتها بالانسحاب.\r\nوكانت خليف قد حُرمت من خوض نهائي بطولة العالم في نيودلهي العام الماضي بسبب عدم استيفاء معايير أهلية الجنس و"مستويات هرمون التستوستيرون" وفقا لملفها الشخصي على نظام معلومات أولمبياد باريس 2024.\r\nوبالرغم من استبعاد خليف والتايوانية يو تينغ لين التي تلعب الجمعة، من بطولة العالم، اعتُبرتا مؤهلتي
# ...
