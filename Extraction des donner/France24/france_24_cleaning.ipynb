# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("fichier_fusionne_2025_2024.csv")  # Replace with your actual file name

# %%
df
# Out:
#        Unnamed: 0     source  \
# 0               0  France 24
# 1               1  France 24
# 2               2  France 24
# 3               3  France 24
# 4               4  France 24
# ...           ...        ...
# 10751          29  France 24
# 10752          30  France 24
# 10753          31  France 24
# 10754          32  France 24
# 10755          33  France 24
#
#                                                    title  \
# 0      الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...                                                  ...
# 10751  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10752            ترامب يعد بتحويل غزة إلى "ريفيرا الشرق"
# 10753  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# ...

# %%
df = df[df['published_at'] != 'No Published Date']

# %%
df.drop(columns=['Unnamed: 0', 'author', 'image_url?'], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\1399685733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Unnamed: 0', 'author', 'image_url?'], inplace=True)

# %%
df.dropna(subset=['description'], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\3633435461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['description'], inplace=True)

# %%
df
# Out:
#           source                                              title  \
# 0      France 24  الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      France 24  محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      France 24  تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      France 24  إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      France 24  خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...          ...                                                ...
# 10750  France 24  قاض فيدرالي يعلق إشراف لجنة ماسك على نظام المد...
# 10751  France 24  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10753  France 24  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# 10754  France 24  وزير الخارجية الأمريكية لن يحضر قمة العشرين في...
# 10755  France 24  ترامب يصدر أمرا تنفيذيا يحظر مشاركة المتحولات ...
#
#                                                  content  \
# 0      \r\nوسط تواصل الجدل بشأنها واستنكار الجزائر ال...
# ...

# %%
df.drop(columns='content',inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\2321816504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='content',inplace=True)

# %%
df.isnull().sum()
# Out:
# source            0
# title             0
# description       0
# url               0
# published_at      0
# tags            323
# dtype: int64

# %%
df.tags.values
# Out:
# array(['\r\n\r\n                                    رياضة\r\n                            ',
#        '\r\n\r\n                                    رياضة\r\n                            ',
#        '\r\n\r\n                                    الشرق الأوسط\r\n                            ',
#        ..., 'أمريكا', 'أمريكا', 'أمريكا'], dtype=object)

# %%
# Nettoyage des tags : supprimer les espaces, sauts de ligne et caractères spéciaux inutiles
df["tags"] = df["tags"].astype(str).str.strip().str.replace(r"\s+", " ", regex=True)

# Compter les occurrences après nettoyage
tag_counts = df["tags"].value_counts().to_dict()

# Afficher le dictionnaire propre
print(tag_counts)
# Out:
# {'الأخبار المغاربية': 3229, 'الشرق الأوسط': 2209, 'أوروبا': 1038, 'أمريكا': 759, 'رياضة': 593, 'فرنسا': 577, 'أفريقيا': 526, 'آسيا': 323, 'nan': 323, 'مجتمع': 275, 'اقتصاد': 162, 'ثقافة': 122, 'علوم': 71, 'No Tags': 6, 'RSS': 1}
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\4023859370.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"] = df["tags"].astype(str).str.strip().str.replace(r"\s+", " ", regex=True)

# %%
df.tags.isnull().sum()
# Out:
# 0

# %%
df["tags"].value_counts().to_dict()
# Out:
# {'الأخبار المغاربية': 3229,
#  'الشرق الأوسط': 2209,
#  'أوروبا': 1038,
#  'أمريكا': 759,
#  'رياضة': 593,
#  'فرنسا': 577,
#  'أفريقيا': 526,
#  'آسيا': 323,
#  'nan': 323,
#  'مجتمع': 275,
#  'اقتصاد': 162,
#  'ثقافة': 122,
#  'علوم': 71,
#  'No Tags': 6,
#  'RSS': 1}

# %%
df
# Out:
#           source                                              title  \
# 0      France 24  الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      France 24  محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      France 24  تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      France 24  إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      France 24  خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...          ...                                                ...
# 10750  France 24  قاض فيدرالي يعلق إشراف لجنة ماسك على نظام المد...
# 10751  France 24  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10753  France 24  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# 10754  France 24  وزير الخارجية الأمريكية لن يحضر قمة العشرين في...
# 10755  France 24  ترامب يصدر أمرا تنفيذيا يحظر مشاركة المتحولات ...
#
#                                              description  \
# 0      \r\n                                        تغ...
# ...

# %%
df["content"] = df["description"].astype(str).str.strip().str.replace(r"\s+", " ", regex=True)
df.drop(columns="description", inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\3452656544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["content"] = df["description"].astype(str).str.strip().str.replace(r"\s+", " ", regex=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\3452656544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns="description", inplace=True)

# %%
df
# Out:
#           source                                              title  \
# 0      France 24  الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      France 24  محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      France 24  تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      France 24  إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      France 24  خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...          ...                                                ...
# 10750  France 24  قاض فيدرالي يعلق إشراف لجنة ماسك على نظام المد...
# 10751  France 24  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10753  France 24  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# 10754  France 24  وزير الخارجية الأمريكية لن يحضر قمة العشرين في...
# 10755  France 24  ترامب يصدر أمرا تنفيذيا يحظر مشاركة المتحولات ...
#
#                                                      url        published_at  \
# ...

# %%
df.columns
# Out:
# Index(['source', 'title', 'url', 'published_at', 'tags', 'content'], dtype='object')

# %%
from datetime import datetime
def normalize_date(date):

     return datetime.strptime(date, "%d/%m/%Y - %H:%M").strftime("%Y-%m-%d")

df["published_at"] = df["published_at"].apply(normalize_date)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\3285604739.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["published_at"] = df["published_at"].apply(normalize_date)

# %%
df
# Out:
#           source                                              title  \
# 0      France 24  الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      France 24  محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      France 24  تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      France 24  إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      France 24  خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...          ...                                                ...
# 10750  France 24  قاض فيدرالي يعلق إشراف لجنة ماسك على نظام المد...
# 10751  France 24  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10753  France 24  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# 10754  France 24  وزير الخارجية الأمريكية لن يحضر قمة العشرين في...
# 10755  France 24  ترامب يصدر أمرا تنفيذيا يحظر مشاركة المتحولات ...
#
#                                                      url published_at  \
# 0      https://www.france24.com/ar/%D8%B1%D9%8A%D8%A7...   2024-08-01
# ...

# %%
df.isnull().sum()
# Out:
# source          0
# title           0
# url             0
# published_at    0
# tags            0
# content         0
# dtype: int64

# %%
df.source='France_24'
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14576\3317512951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.source='France_24'

# %%
df
# Out:
#           source                                              title  \
# 0      France_24  الألعاب الأولمبية: الملاكمة خليف تبلغ ربع النه...
# 1      France_24  محطة أفريقيا في الألعاب الأولمبية بباريس: "خيم...
# 2      France_24  تنديدا باغتيال هنية... مظاهرات مناهضة لإسرائيل...
# 3      France_24  إسرائيل "تغتال" صحفيا ومصورا من قناة الجزيرة ف...
# 4      France_24  خليل الحية عن اغتيال هنية.. هذه جريمة لا بد لم...
# ...          ...                                                ...
# 10750  France_24  قاض فيدرالي يعلق إشراف لجنة ماسك على نظام المد...
# 10751  France_24  مخطط دونالد ترامب لتهجير سكان قطاع غزة بين الو...
# 10753  France_24  الولايات المتحدة تأمر بوقف عشرات المنح المقدمة...
# 10754  France_24  وزير الخارجية الأمريكية لن يحضر قمة العشرين في...
# 10755  France_24  ترامب يصدر أمرا تنفيذيا يحظر مشاركة المتحولات ...
#
#                                                      url published_at  \
# 0      https://www.france24.com/ar/%D8%B1%D9%8A%D8%A7...   2024-08-01
# ...

# %%
df.to_csv('france_24_clened_data.csv',index=False)

# %%
df["published_at"].value_counts().to_dict()
# Out:
# {'No Published Date': 201,
#  '\r\n                04 ديسمبر 2024\r\n            ': 32,
#  '\r\n                20 يناير 2025\r\n            ': 7,
#  '\r\n                03 ديسمبر 2024\r\n            ': 5,
#  '18/02/2025 - 14:48': 4,
#  '18/02/2025 - 17:07': 4,
#  '18/02/2025 - 14:45': 4,
#  '\r\n                16 يناير 2025\r\n            ': 4,
#  '\r\n                28 يناير 2025\r\n            ': 4,
#  '\r\n                21 أكتوبر 2024\r\n            ': 4,
#  '17/02/2025 - 22:19': 4,
#  '\r\n                31 أكتوبر 2024\r\n            ': 3,
#  '\r\n                23 سبتمبر 2024\r\n            ': 3,
#  '28/01/2025 - 22:12': 3,
#  '10/02/2025 - 16:00': 3,
#  '13/02/2025 - 14:09': 3,
#  '\r\n                09 أغسطس 2024\r\n            ': 3,
#  '23/05/2024 - 22:21': 3,
#  '\r\n                29 أكتوبر 2024\r\n            ': 3,
#  '31/01/2025 - 16:18': 3,
#  '30/10/2024 - 22:09': 3,
#  '\r\n                26 يوليو 2024\r\n            ': 3,
#  '21/05/2024 - 02:38': 3,
# ...
