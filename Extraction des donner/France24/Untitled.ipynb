# %%
import os
import pandas as pd

# Chemin du dossier contenant les fichiers CSV
dossier_csv = "data"

# Liste pour stocker les DataFrames
dataframes = []

# Lire tous les fichiers CSV contenant "2025" dans le nom
for fichier in os.listdir(dossier_csv):
    if fichier.endswith(".csv") and "2025" in fichier:
        chemin_fichier = os.path.join(dossier_csv, fichier)
        df = pd.read_csv(chemin_fichier)
        dataframes.append(df)

# Fusionner tous les DataFrames
df_fusionne = pd.concat(dataframes, ignore_index=True)

# Enregistrer le résultat dans un nouveau fichier CSV
df_fusionne.to_csv("fichier_fusionne_2025.csv", index=False)

print("Fusion terminée ! Fichier enregistré sous 'fichier_fusionne_2025.csv'.")
# Out:
# Fusion terminée ! Fichier enregistré sous 'fichier_fusionne_2025.csv'.

# %%
df_fusionne
# Out:
#      Unnamed: 0     source                                              title  \
# 0             0  France 24  لبنان: عون يدين غارة إسرائيلية على الضاحية الج...
# 1             1  France 24                  فرنسا - الجزائر: هل يخف الاحتقان؟
# 2             2  France 24  بعد إدانة لوبان، جدل في فرنسا حول جوهر الديمقر...
# 3             3  France 24  العاهل المغربي يصدر عفوا عن عبد القادر بلعيرج ...
# 4             4  France 24                  فرنسا - الجزائر: هل انتهت الأزمة؟
# ...         ...        ...                                                ...
# 4287         42  France 24  مشروع قانون يفرض قيودا على الهجرة والمهاجرين.....
# 4288         43  France 24  صناعة السجاد في المغرب.. حرفة تراثية مهددة بال...
# 4289         44  France 24  القوات الروسية تعلن السيطرة على قرية جديدة في ...
# 4290         45  France 24  المعارك في السودان: الجيش يعلن استعادة مدينة أ...
# 4291         46  France 24                       مميعات الدم.. متى تؤخذ وكيف؟
#
#                                                 content  \
# 0     \n\nشن الجيش الإسرائيلي غارة جوية فجر الثلاثاء...
# 1                                                   NaN
# 2                                                   NaN
# 3     \nاستفاد البلجيكي المغربي عبد القادر بلعيرج من...
# 4                                                   NaN
# ...                                                 ...
# 4287                                                NaN
# 4288                                                NaN
# 4289                                                NaN
# 4290  \nقال الجيش السوداني الخميس إنه استعاد السيطرة...
# 4291                                                NaN
#
#                                             description  \
# 0     \n                                        شن ا...
# 1     \n                                            ...
# 2     \n                                            ...
# 3     \n                                        بعد ...
# 4     \n                                            ...
# ...                                                 ...
# 4287  \n                                            ...
# 4288  \n                                            ...
# 4289  \n                                            ...
# 4290  \n                                        أكد ...
# 4291  \n                                            ...
#
#                                                     url        published_at  \
# 0     https://www.france24.com/ar/%D8%A7%D9%84%D8%B4...  01/04/2025 - 03:38
# 1     https://www.france24.com/ar/%D8%A8%D8%B1%D8%A7...  01/04/2025 - 20:46
# 2     https://www.france24.com/ar/%D9%81%D9%8A%D8%AF...  01/04/2025 - 10:05
# 3     https://www.france24.com/ar/%D8%A7%D9%84%D8%A3...  01/04/2025 - 17:07
# 4     https://www.france24.com/ar/%D9%81%D9%8A%D8%AF...  01/04/2025 - 22:15
# ...                                                 ...                 ...
# 4287  https://www.france24.com/ar/%D9%81%D9%8A%D8%AF...  31/01/2025 - 15:44
# 4288  https://www.france24.com/ar/%D9%81%D9%8A%D8%AF...  31/01/2025 - 16:18
# 4289  https://www.france24.com/ar/%D9%81%D9%8A%D8%AF...  31/01/2025 - 13:57
# 4290  https://www.france24.com/ar/%D8%AB%D9%82%D8%A7...  31/01/2025 - 12:56
# 4291  https://www.france24.com/ar/%D8%A8%D8%B1%D8%A7...  31/01/2025 - 11:23
#
#                                                    tags
# 0     \n\n                                    الشرق ...
# 1     \n\n                                    فرنسا\...
# 2     \n\n                                    فرنسا\...
# 3     \n\n                                    الأخبا...
# 4     \n\n                                    الأخبا...
# ...                                                 ...
# 4287  \n                                    فرنسا\n ...
# 4288  \n                                    فرنسا\n ...
# 4289  \n\n                                    أوروبا...
# 4290  \n\n                                    ثقافة\...
# 4291  \n\n                                    علوم\n...
#
# [4292 rows x 8 columns]
