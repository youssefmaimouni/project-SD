# %%
import os
import pandas as pd

# Chemin du dossier contenant les fichiers CSV
dossier_csv = "./"

# Liste pour stocker les DataFrames
dataframes = []

# Lire tous les fichiers CSV du dossier
for fichier in os.listdir(dossier_csv):
    if fichier.endswith(".csv"):
        chemin_fichier = os.path.join(dossier_csv, fichier)
        df = pd.read_csv(chemin_fichier)
        dataframes.append(df)

# Fusionner tous les DataFrames
df_fusionne = pd.concat(dataframes, ignore_index=True)

# Enregistrer le résultat dans un nouveau fichier CSV


print("Fusion terminée ! Fichier enregistré sous 'fichier_fusionne.csv'.")
# Out:
# Fusion terminée ! Fichier enregistré sous 'fichier_fusionne.csv'.

# %%
df_fusionne.duplicated().sum()
# Out:
# 9919

# %%
df_fusionne.shape
# Out:
# (24729, 9)

# %%
df_fusionne.drop_duplicates(inplace=True)
df_fusionne
# Out:
#          source                   author  \
# 0      Al Hurra  الحرة / وكالات - واشنطن
# 1      Al Hurra           الحرة - واشنطن
# 2      Al Hurra         يحيى قاسم- القدس
# 3      Al Hurra           الحرة - واشنطن
# 4      Al Hurra       زيد الزايدي - تونس
# ...         ...                      ...
# 18389  Al Hurra  الحرة / وكالات - واشنطن
# 18676  Al Hurra  الحرة / وكالات - واشنطن
# 20003  Al Hurra                      NaN
# 20562  Al Hurra                فرانس برس
# 21958  Al Hurra       ميادة داود - بغداد
#
#                                                    title  \
# 0      قبل سقوط الأسد أم بعده؟.. حقيقة فيديو متداول ل...
# 1      الاتحاد الأوروبي يهدد برد "حازم وسريع" على تعر...
# 2      قبل موعد قُرّر في مصر.. نتانياهو: غدا سيكون يو...
# 3      "كوميدي وديكتاتور".. ترامب لزيلينسكي: تحرك بسر...
# 4      سعيد لم يهنئ الشرع.. ماذا وراء موقف تونس من "س...
# ...                                                  ...
# 18389  قوة بحرية: قراصنة يستولون على سفينة صيد صينية ...
# 18676  بعد كاليفورنيا.. ولاية أميركية أخرى تستعد "لحظ...
# 20003                           ترامب: لقد كتبنا التاريخ
# 20562                حقيقة فيديو "بيع أصنام" في السعودية
# 21958  إبراهيم ومجتبى.. جرح قمع "احتجاجات تشرين" في ا...
#
#                                                  content  \
# 0      انتشر على مواقع التواصل الاجتماعي مؤخراً فيديو...
# 1      أعلن المفوض الأوروبي للتجارة، ماروس سيفكوفيتش،...
# 2      اعتبر رئيس الوزراء الإسرائيلي بنيامين نتانياهو...
# 3      وجه الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 4      خلافا لجل العواصم العربية، لم ترسل تونس بعد أي...
# ...                                                  ...
# 18389  أعلنت وزارة الصحة الفلسطينية في قطاع غزة، الأر...
# 18676  جدد الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 20003                                                NaN
# 20562  تداولت صفحات وحسابات على مواقع التواصل الاجتما...
# 21958  كشف السفير العراقي لدى الكويت، المنهل الصافي، ...
#
#                                              description  \
# 0      انتشر على مواقع التواصل الاجتماعي مؤخراً فيديو...
# 1      أعلن المفوض الأوروبي للتجارة، ماروس سيفكوفيتش،...
# 2      اعتبر رئيس الوزراء الإسرائيلي بنيامين نتانياهو...
# 3      وجه الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 4      خلافا لجل العواصم العربية، لم ترسل تونس بعد أي...
# ...                                                  ...
# 18389  قالت قوة مكافحة القرصنة البحرية التابعة للاتحا...
# 18676  يستعد مشرعون في مدينة بوسطن بولاية ماساتشوستس ...
# 20003  أعلن المرشح الجمهوري لانتخابات الرئاسة الأميرك...
# 20562  تداولت صفحات وحسابات على مواقع التواصل الاجتما...
# 21958  خلال محاولته توثيق قمع القوات الأمنية في العرا...
#
#                                                      url  \
# 0      https://www.alhurra.com/syria/2025/02/19/%D8%B...
# 1      https://www.alhurra.com/latest/2025/02/19/%D8%...
# 2      https://www.alhurra.com/israel/2025/02/19/%D9%...
# 3      https://www.alhurra.com/usa/2025/02/19/%D9%83%...
# 4      https://www.alhurra.com/tunisia/2025/02/19/%D8...
# ...                                                  ...
# 18389  https://www.alhurra.com/arabic-and-internation...
# 18676  https://www.alhurra.com/usa/2024/11/30/%D9%83%...
# 20003  https://www.alhurra.com/us-election-2024/2024/...
# 20562  https://www.alhurra.com/hl-hqa/2024/10/27/%D8%...
# 21958  https://www.alhurra.com/iraq/2024/10/02/%D8%A5...
#
#                                                image_url published_at  \
# 0      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 1      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 2      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 3      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 4      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# ...                                                  ...          ...
# 18389  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-12-05
# 18676  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-11-30
# 20003  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-11-06
# 20562  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-10-27
# 21958  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-10-02
#
#               tags
# 0        ['الأسد']
# 1        ['ترامب']
# 2      ['إسرائيل']
# 3        ['ترامب']
# 4        ['سوريا']
# ...            ...
# 18389           []
# 18676           []
# 20003           []
# 20562           []
# 21958           []
#
# [14810 rows x 9 columns]

# %%
df_fusionne.to_csv("alhura_full_data.csv", index=False)

# %%
import pandas as pd
from pymongo.mongo_client import MongoClient

# MongoDB Atlas connection URI
uri = "mongodb+srv://team_member:projectSD_Media1@cluster0.m6cwo.mongodb.net/projectSD?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(uri)

# Select Database and Collection
db = client["projectSD"]  # Change to your database name
collection = db["alhura"]  # Change to your collection name

# Load CSV into DataFrame
csv_file = "alhura_full_data.csv"  # Replace with the actual CSV file path
df = pd.read_csv(csv_file)

# Convert DataFrame to Dictionary
data = df.to_dict(orient="records")

# Insert Data into MongoDB Atlas
if data:  # Check if data is not empty
    collection.insert_many(data)
    print("✅ CSV data successfully inserted into MongoDB Atlas!")
else:
    print("⚠️ CSV file is empty. No data inserted.")

# Close the connection (optional)
client.close()
# Out:
# ✅ CSV data successfully inserted into MongoDB Atlas!
