# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("alhura_full_data.csv")  # Replace with your actual file name

# Count occurrences and convert to dictionary
tag_counts = df["tags"].value_counts().to_dict()


tag_counts
# Out:
# {'[]': 10082,
#  "['إسرائيل']": 887,
#  "['ترامب']": 656,
#  "['سوريا']": 402,
#  "['غزة']": 331,
#  "['الأسد']": 187,
#  "['إسرائيل', 'غزة']": 132,
#  "['إسرائيل', 'الإسرائيلي', 'الجيش الإسرائيلي']": 132,
#  "['الأميركية', 'الأميركي']": 125,
#  "['أميركا']": 115,
#  "['إسرائيل', 'الإسرائيلي']": 111,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية']": 102,
#  "['الأميركي']": 98,
#  "['السورية']": 80,
#  "['غزة', 'ترامب']": 74,
#  "['الرئيس']": 64,
#  "['حماس']": 61,
#  "['الولايات المتحدة']": 61,
#  "['سوريا', 'الأسد']": 57,
#  "['إسرائيل', 'سوريا']": 51,
#  "['انتخابات']": 49,
#  "['انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي']": 43,
#  "['حماس', 'إسرائيل']": 39,
#  "['إسرائيل', 'غزة', 'الإسرائيلي', 'الجيش الإسرائيلي']": 30,
#  "['ترامب', 'أميركا']": 30,
#  "['انتخابات', 'الانتخابات']": 29,
#  "['ترامب', 'الأميركي']": 25,
#  "['حماس', 'غزة']": 23,
#  "['إسرائيل', 'ترامب']": 22,
#  "['السوريين']": 20,
#  "['ترامب', 'الأميركية', 'الأميركي']": 19,
#  "['ترامب', 'انتخابات', 'الانتخابات']": 16,
#  "['بشار', 'الأسد']": 14,
#  "['انتخابات', 'الانتخابات', 'الرئاسية']": 14,
#  "['فلسطينية', 'الفلسطينية']": 13,
#  "['المرشح']": 13,
#  "['التصويت']": 12,
#  "['ترامب', 'الرئيس']": 12,
#  "['سوريا', 'الأميركية', 'الأميركي']": 11,
#  "['أميركا', 'انتخابات']": 10,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'سوريا']": 10,
#  "['إسرائيل', 'الأميركي']": 10,
#  "['الأميركي', 'الرئيس']": 10,
#  "['إسرائيل', 'غزة', 'الإسرائيلي']": 10,
#  "['إسرائيل', 'السورية']": 10,
#  "['الأسد', 'السورية']": 10,
#  "['نيران']": 10,
#  "['فلسطينية']": 9,
#  "['إسرائيل', 'الأسد']": 9,
#  "['إسرائيل', 'الإسرائيلي', 'الجيش الإسرائيلي', 'سوريا']": 9,
#  "['إسرائيل', 'الأميركية', 'الأميركي']": 9,
#  "['إسرائيل', 'فلسطينية', 'الفلسطينية']": 9,
#  "['إسرائيل', 'غزة', 'الإسرائيلي', 'الإسرائيلية']": 8,
#  "['إسرائيل', 'أميركا']": 8,
#  "['أسرى']": 8,
#  "['إسرائيل', 'الولايات المتحدة']": 8,
#  "['إسرائيل', 'الرئيس']": 8,
#  "['الرئاسة الأميركية', 'انتخابات', 'الأميركية', 'الأميركي']": 8,
#  "['كاليفورنيا']": 7,
#  "['ترامب', 'انتخابات']": 7,
#  "['ترامب', 'الولايات المتحدة']": 7,
#  "['حرائق', 'لوس أنجلوس', 'لوس', 'أنجلوس']": 7,
#  "['حماس', 'إسرائيل', 'الإسرائيلي']": 7,
#  "['الفلسطينيين']": 7,
#  "['سوريا', 'الأميركي']": 7,
#  "['الرئاسة الأميركية', 'الأميركية', 'الأميركي']": 7,
#  "['سوريا', 'ترامب']": 6,
#  "['لوس']": 6,
#  "['الأسد', 'السوريين']": 6,
#  "['حماس', 'إسرائيل', 'غزة']": 6,
#  "['إسرائيل', 'غزة', 'ترامب']": 6,
#  "['حماس', 'إسرائيل', 'الإسرائيلي', 'الجيش الإسرائيلي']": 6,
#  "['غزة', 'الأميركي']": 6,
#  "['سوريا', 'أميركا']": 5,
#  "['إسرائيل', 'الفلسطينيين']": 5,
#  "['ترامب', 'الانتخابية']": 5,
#  "['انتخابات', 'الأميركي']": 5,
#  "['حماس', 'ترامب']": 5,
#  "['الانتخابية']": 5,
#  "['حرائق', 'كاليفورنيا']": 4,
#  "['لوس أنجلوس', 'لوس', 'أنجلوس']": 4,
#  "['نتنياهو']": 4,
#  "['حماس', 'إسرائيل', 'غزة', 'الإسرائيلي', 'الجيش الإسرائيلي']": 4,
#  "['الخسائر']": 4,
#  "['إسرائيل', 'الخسائر']": 4,
#  "['إسرائيل', 'الإسرائيلي', 'سوريا']": 4,
#  "['غزة', 'الأميركية', 'الأميركي']": 4,
#  "['انتخابات', 'الأميركية', 'الانتخابات', 'الأميركي', 'الرئاسية']": 4,
#  "['الفلسطينيين', 'ترامب']": 4,
#  "['ترامب', 'انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي']": 3,
#  "['حرائق', 'الحرائق']": 3,
#  "['المقاومة']": 3,
#  "['أميركا', 'انتخابات', 'الانتخابات']": 3,
#  "['ترامب', 'الولاية']": 3,
#  "['انتخابات', 'الرئاسية']": 3,
#  "['انتخابات', 'الأميركية', 'الأميركي']": 3,
#  "['ترامب', 'الرئاسة الأميركية', 'الأميركية', 'الأميركي']": 3,
#  "['غزة', 'سوريا']": 3,
#  "['سوريا', 'الولايات المتحدة']": 3,
#  "['انتخابات', 'الانتخابات', 'الولايات المتحدة']": 3,
#  "['بشار']": 3,
#  "['إسرائيل', 'سوريا', 'الأسد']": 3,
#  "['حرائق']": 3,
#  "['الفلسطينيين', 'غزة']": 3,
#  "['حماس', 'إسرائيل', 'ترامب']": 3,
#  "['الفلسطينيين', 'غزة', 'ترامب']": 3,
#  "['إسرائيل', 'الإسرائيلي', 'ترامب']": 3,
#  "['غزة', 'الولايات المتحدة']": 3,
#  "['إسرائيل', 'فلسطينية']": 3,
#  "['مقاطعة']": 2,
#  "['انتخابات', 'الانتخابات', 'الأميركي']": 2,
#  "['إسرائيل', 'غزة', 'الأميركية', 'الأميركي']": 2,
#  "['سوريا', 'انتخابات']": 2,
#  "['إسرائيل', 'غزة', 'الإسرائيلي', 'الأميركي']": 2,
#  "['ترامب', 'أميركا', 'انتخابات']": 2,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'الولايات المتحدة']": 2,
#  "['ولاية ثانية']": 2,
#  "['غزة', 'لوس']": 2,
#  "['إسرائيل', 'نيران']": 2,
#  "['حماس', 'لوس']": 2,
#  "['دونالد']": 2,
#  "['ترامب', 'التصويت']": 2,
#  "['انتخابات', 'الرئيس']": 2,
#  "['ترامب', 'الرئاسية']": 2,
#  "['ترامب', 'كاليفورنيا']": 2,
#  "['غزة', 'انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي']": 2,
#  "['بشار', 'الأسد', 'السورية']": 2,
#  "['ترامب', 'انتخابات', 'الانتخابات', 'الرئاسية']": 2,
#  "['الأميركي', 'المرشح']": 2,
#  "['غزة', 'أميركا']": 2,
#  "['إسرائيل', 'الإسرائيلي', 'الأميركي']": 2,
#  "['دونالد', 'ترامب']": 2,
#  "['غزة', 'سوريا', 'ترامب']": 2,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'السورية']": 2,
#  "['حرائق', 'الحرائق', 'لوس أنجلوس', 'لوس', 'أنجلوس']": 2,
#  "['انتخابات', 'الأميركية', 'الأميركي', 'الرئاسية']": 2,
#  "['غزة', 'الرئيس']": 2,
#  "['سوريا', 'السورية']": 2,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'الخسائر']": 2,
#  "['الأميركي', 'حرائق', 'كاليفورنيا']": 2,
#  "['انتخابات', 'الانتخابات', 'الرئيس']": 2,
#  "['غزة', 'فلسطينية', 'الفلسطينية']": 2,
#  "['سوريا', 'انتخابات', 'الانتخابات']": 2,
#  "['حماس', 'انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي', 'التصويت']": 1,
#  "['دونالد', 'أميركا']": 1,
#  "['الأميركي', 'التصويت']": 1,
#  "['إسرائيل', 'فلسطينية', 'الإسرائيلي']": 1,
#  "['غزة', 'فلسطينية']": 1,
#  "['الأميركية', 'الأميركي', 'المرشح']": 1,
#  "['الرئاسة الأميركية', 'انتخابات', 'الأميركية', 'الأميركي', 'التصويت']": 1,
#  "['إسرائيل', 'غزة', 'نيران']": 1,
#  "['انتخابات', 'الانتخابات', 'التصويت']": 1,
#  "['حماس', 'غزة', 'الأميركية', 'الأميركي']": 1,
#  "['إسرائيل', 'غزة', 'فلسطينية']": 1,
#  "['غزة', 'مقاطعة', 'المقاطعة']": 1,
#  "['الرئاسية']": 1,
#  "['غزة', 'لوس أنجلوس', 'لوس', 'أنجلوس']": 1,
#  "['إسرائيل', 'سوريا', 'لوس']": 1,
#  "['إسرائيل', 'حرائق', 'اندلاع حرائق']": 1,
#  "['إسرائيل', 'فلسطينية', 'الإسرائيلي', 'الرئيس']": 1,
#  "['حماس', 'الولايات المتحدة']": 1,
#  "['إسرائيل', 'غزة', 'أميركا']": 1,
#  "['ترامب', 'انتخابات', 'الانتخابات', 'الانتخابية']": 1,
#  "['حماس', 'إسرائيل', 'الأميركي']": 1,
#  "['إسرائيل', 'غزة', 'الأميركي']": 1,
#  "['حماس', 'إسرائيل', 'الإسرائيلي', 'الجيش الإسرائيلي', 'سوريا']": 1,
#  "['إسرائيل', 'حرائق']": 1,
#  "['إسرائيل', 'الفلسطينيين', 'الإسرائيلي']": 1,
#  "['انتخابات', 'الأميركية', 'الأميركي', 'الرئاسية', 'المرشح']": 1,
#  "['انتخابات', 'المرشح']": 1,
#  "['ترامب', 'الأميركي', 'المرشح']": 1,
#  "['أميركا', 'انتخابات', 'الرئيس']": 1,
#  "['حماس', 'انتخابات', 'الأميركي']": 1,
#  "['غزة', 'انتخابات', 'الانتخابات']": 1,
#  "['غزة', 'انتخابات']": 1,
#  "['سوريا', 'لوس']": 1,
#  "['إسرائيل', 'نتنياهو', 'الإسرائيلي']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'أميركا']": 1,
#  "['إسرائيل', 'انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي']": 1,
#  "['أميركا', 'انتخابات', 'التصويت']": 1,
#  "['مقاطعة', 'انتخابات']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'الأميركية', 'الأميركي']": 1,
#  "['الرئيس', 'لوس']": 1,
#  "['انتخابات', 'الانتخابات', 'المرشح']": 1,
#  "['إسرائيل', 'حرائق', 'الحرائق']": 1,
#  "['مقاطعة', 'المقاطعة']": 1,
#  "['إسرائيل', 'غزة', 'الإسرائيلي', 'الجيش الإسرائيلي', 'ترامب']": 1,
#  "['مقاطعة', 'ترامب']": 1,
#  "['فلسطينية', 'الفلسطينية', 'الأسد']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'الأسد']": 1,
#  "['بشار', 'الأسد', 'ترامب']": 1,
#  "['الولايات المتحدة', 'لوس أنجلوس', 'لوس', 'أنجلوس']": 1,
#  "['إسرائيل', 'سوريا', 'أميركا']": 1,
#  "['السورية', 'الأميركي']": 1,
#  "['السوريين', 'أميركا']": 1,
#  "['إسرائيل', 'السورية', 'الأميركية', 'الأميركي']": 1,
#  "['سوريا', 'بشار', 'الأسد']": 1,
#  "['كاليفورنيا', 'نيران']": 1,
#  "['السورية', 'الولايات المتحدة']": 1,
#  "['حرائق', 'لوس']": 1,
#  "['إسرائيل', 'نتنياهو']": 1,
#  "['الأسد', 'الرئيس']": 1,
#  "['الأسد', 'الأميركي']": 1,
#  "['ترامب', 'أميركا', 'الأميركي']": 1,
#  "['إسرائيل', 'فلسطينية', 'الإسرائيلي', 'الجيش الإسرائيلي', 'الفلسطينية']": 1,
#  "['حماس', 'إسرائيل', 'الإسرائيلي', 'الإسرائيلية']": 1,
#  "['ترامب', 'أميركا', 'حرائق', 'لوس أنجلوس', 'لوس', 'أنجلوس']": 1,
#  "['حرائق', 'الغابات', 'لوس']": 1,
#  "['غزة', 'حرائق', 'كاليفورنيا']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'الجيش الإسرائيلي', 'السورية']": 1,
#  "['ترامب', 'حرائق', 'كاليفورنيا']": 1,
#  "['سوريا', 'الأميركي', 'الرئيس']": 1,
#  "['حماس', 'غزة', 'فلسطينية', 'الفلسطينية']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'الإسرائيلية', 'الأسد']": 1,
#  "['سوريا', 'الأسد', 'ترامب']": 1,
#  "['انتخابات', 'الأميركية', 'الانتخابات', 'الانتخابات الأميركية', 'الأميركي', 'التصويت']": 1,
#  "['ترامب', 'الأميركي', 'الرئيس']": 1,
#  "['غزة', 'سوريا', 'أميركا']": 1,
#  "['انتخابات', 'التصويت']": 1,
#  "['حماس', 'إسرائيل', 'فلسطينية', 'الفلسطينية']": 1,
#  "['ترامب', 'المرشح', 'الرئيس']": 1,
#  "['المقاومة', 'المقاومة الإسلامية']": 1,
#  "['أميركا', 'الرئيس']": 1,
#  "['إسرائيل', 'غزة', 'ترامب', 'أميركا']": 1,
#  "['سوريا', 'ترامب', 'الأميركية', 'الأميركي']": 1,
#  "['مقاطعة', 'أميركا']": 1,
#  "['فلسطينية', 'ترامب']": 1,
#  "['المقاومة', 'المقاومة الإسلامية', 'ترامب', 'الأميركية', 'الأميركي']": 1,
#  "['ترامب', 'أميركا', 'الانتخابية']": 1,
#  "['سوريا', 'ترامب', 'الرئيس']": 1,
#  "['غزة', 'ترامب', 'أميركا']": 1,
#  "['ترامب', 'المرشح']": 1,
#  "['حماس', 'القسام']": 1,
#  "['إسرائيل', 'فلسطينية', 'ترامب']": 1,
#  "['إسرائيل', 'الإسرائيلي', 'السورية']": 1,
#  "['الولاية']": 1,
#  "['حماس', 'الأميركي']": 1,
#  "['السورية', 'الرئيس']": 1,
#  "['إسرائيل', 'الفلسطينيين', 'غزة']": 1,
#  "['الأميركية', 'الأميركي', 'نيران']": 1,
#  "['السورية', 'ترامب']": 1,
#  "['بشار', 'السورية']": 1}

# %%
df
# Out:
#          source                   author  \
# 0      Al Hurra  الحرة / وكالات - واشنطن
# 1      Al Hurra           الحرة - واشنطن
# 2      Al Hurra         يحيى قاسم- القدس
# 3      Al Hurra           الحرة - واشنطن
# 4      Al Hurra       زيد الزايدي - تونس
# ...         ...                      ...
# 14805  Al Hurra  الحرة / وكالات - واشنطن
# 14806  Al Hurra  الحرة / وكالات - واشنطن
# 14807  Al Hurra                      NaN
# 14808  Al Hurra                فرانس برس
# 14809  Al Hurra       ميادة داود - بغداد
#
#                                                    title  \
# 0      قبل سقوط الأسد أم بعده؟.. حقيقة فيديو متداول ل...
# 1      الاتحاد الأوروبي يهدد برد "حازم وسريع" على تعر...
# 2      قبل موعد قُرّر في مصر.. نتانياهو: غدا سيكون يو...
# 3      "كوميدي وديكتاتور".. ترامب لزيلينسكي: تحرك بسر...
# 4      سعيد لم يهنئ الشرع.. ماذا وراء موقف تونس من "س...
# ...                                                  ...
# 14805  قوة بحرية: قراصنة يستولون على سفينة صيد صينية ...
# 14806  بعد كاليفورنيا.. ولاية أميركية أخرى تستعد "لحظ...
# 14807                           ترامب: لقد كتبنا التاريخ
# 14808                حقيقة فيديو "بيع أصنام" في السعودية
# 14809  إبراهيم ومجتبى.. جرح قمع "احتجاجات تشرين" في ا...
#
#                                                  content  \
# 0      انتشر على مواقع التواصل الاجتماعي مؤخراً فيديو...
# 1      أعلن المفوض الأوروبي للتجارة، ماروس سيفكوفيتش،...
# 2      اعتبر رئيس الوزراء الإسرائيلي بنيامين نتانياهو...
# 3      وجه الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 4      خلافا لجل العواصم العربية، لم ترسل تونس بعد أي...
# ...                                                  ...
# 14805  أعلنت وزارة الصحة الفلسطينية في قطاع غزة، الأر...
# 14806  جدد الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 14807                                                NaN
# 14808  تداولت صفحات وحسابات على مواقع التواصل الاجتما...
# 14809  كشف السفير العراقي لدى الكويت، المنهل الصافي، ...
#
#                                              description  \
# 0      انتشر على مواقع التواصل الاجتماعي مؤخراً فيديو...
# 1      أعلن المفوض الأوروبي للتجارة، ماروس سيفكوفيتش،...
# 2      اعتبر رئيس الوزراء الإسرائيلي بنيامين نتانياهو...
# 3      وجه الرئيس الأميركي دونالد ترامب، الأربعاء، ان...
# 4      خلافا لجل العواصم العربية، لم ترسل تونس بعد أي...
# ...                                                  ...
# 14805  قالت قوة مكافحة القرصنة البحرية التابعة للاتحا...
# 14806  يستعد مشرعون في مدينة بوسطن بولاية ماساتشوستس ...
# 14807  أعلن المرشح الجمهوري لانتخابات الرئاسة الأميرك...
# 14808  تداولت صفحات وحسابات على مواقع التواصل الاجتما...
# 14809  خلال محاولته توثيق قمع القوات الأمنية في العرا...
#
#                                                      url  \
# 0      https://www.alhurra.com/syria/2025/02/19/%D8%B...
# 1      https://www.alhurra.com/latest/2025/02/19/%D8%...
# 2      https://www.alhurra.com/israel/2025/02/19/%D9%...
# 3      https://www.alhurra.com/usa/2025/02/19/%D9%83%...
# 4      https://www.alhurra.com/tunisia/2025/02/19/%D8...
# ...                                                  ...
# 14805  https://www.alhurra.com/arabic-and-internation...
# 14806  https://www.alhurra.com/usa/2024/11/30/%D9%83%...
# 14807  https://www.alhurra.com/us-election-2024/2024/...
# 14808  https://www.alhurra.com/hl-hqa/2024/10/27/%D8%...
# 14809  https://www.alhurra.com/iraq/2024/10/02/%D8%A5...
#
#                                                image_url published_at  \
# 0      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 1      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 2      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 3      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# 4      data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2025-02-19
# ...                                                  ...          ...
# 14805  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-12-05
# 14806  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-11-30
# 14807  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-11-06
# 14808  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-10-27
# 14809  data:image/svg+xml;charset=utf-8,%3Csvg%20xmln...   2024-10-02
#
#               tags
# 0        ['الأسد']
# 1        ['ترامب']
# 2      ['إسرائيل']
# 3        ['ترامب']
# 4        ['سوريا']
# ...            ...
# 14805           []
# 14806           []
# 14807           []
# 14808           []
# 14809           []
#
# [14810 rows x 9 columns]
