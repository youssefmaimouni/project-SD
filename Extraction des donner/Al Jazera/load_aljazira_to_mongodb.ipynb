# %%
import pandas as pd

# %%
df=pd.read_csv('aljazira_articles.csv')
df
# Out:
#                                                   Title  \
# 0             الإفراج عن صحفي تونسي بارز من معارضي سعيد
# 1            أكثر من 111 ألف جريح في غزة ينتظرون العلاج
# 2     المبعوثة الأممية الجديدة: لن ندخر أي جهد لإحلا...
# 3     حماس تتهم نتنياهو بالمماطلة وويتكوف يدافع عن خ...
# 4     رئيس البرازيل يتهم ترامب بتقديم نفسه "إمبراطور...
# ...                                                 ...
# 9985  عائلات الأسرى الإسرائيليين: نتنياهو لم يعلن ال...
# 9986  شهيد برصاص الاحتلال في طولكرم والطيران الحربي ...
# 9987  "موند أفريك": هؤلاء الطغاة الذين صنعوا مصائب أ...
# 9988  معاريف: نتنياهو في واشنطن والأرض تحترق تحت قدم...
# 9989  هل يستطيع الرئيس رامافوزا النجاة من نكسة حزب ا...
#
#                                                 Content       Date
# 0     أفرجت محكمة تونسية، اليوم الخميس، عن الصحفي ال...  2025/2/20
# 1     نشر مكتب الأسرى والجرحى والشهداء في غزة، اليوم...  2025/2/20
# 2     تعهدت مبعوثةالأمم المتحدةالجديدة إلىليبياهانا ...  2025/2/20
# 3     اتهمت حركة المقاومة الإسلامية (حماس) رئيس الوز...  2025/2/20
# 4     اتهم الرئيس البرازيليلولا دا سيلفانظيره الأمير...  2025/2/20
# ...                                                 ...        ...
# 9985  انتقدت هيئة عائلات الأسرى الإسرائيليين المحتجز...  2025/1/25
# 9986  أعلنت وزارة الصحة الفلسطينية استشهاد شاب برصاص...  2025/1/29
# 9987                                                      2020/2/4
# 9988  في وقت يعقد فيه رئيس الوزراء الإسرائيليبنيامين...   2025/2/4
# 9989  شولا لاوال-خسر حزب المؤتمر الوطني الأفريقي الح...   2024/6/2
#
# [9990 rows x 3 columns]

# %%
df.duplicated().sum()
# Out:
# 48

# %%
df.isnull().sum()
# Out:
# Title      0
# Content    6
# Date       3
# dtype: int64

# %%
df["source"] = "al jazi"
df
# Out:
#                                                   Title  \
# 0             الإفراج عن صحفي تونسي بارز من معارضي سعيد
# 1            أكثر من 111 ألف جريح في غزة ينتظرون العلاج
# 2     المبعوثة الأممية الجديدة: لن ندخر أي جهد لإحلا...
# 3     حماس تتهم نتنياهو بالمماطلة وويتكوف يدافع عن خ...
# 4     رئيس البرازيل يتهم ترامب بتقديم نفسه "إمبراطور...
# ...                                                 ...
# 9985  عائلات الأسرى الإسرائيليين: نتنياهو لم يعلن ال...
# 9986  شهيد برصاص الاحتلال في طولكرم والطيران الحربي ...
# 9987  "موند أفريك": هؤلاء الطغاة الذين صنعوا مصائب أ...
# 9988  معاريف: نتنياهو في واشنطن والأرض تحترق تحت قدم...
# 9989  هل يستطيع الرئيس رامافوزا النجاة من نكسة حزب ا...
#
#                                                 Content       Date   source
# 0     أفرجت محكمة تونسية، اليوم الخميس، عن الصحفي ال...  2025/2/20  skynews
# 1     نشر مكتب الأسرى والجرحى والشهداء في غزة، اليوم...  2025/2/20  skynews
# 2     تعهدت مبعوثةالأمم المتحدةالجديدة إلىليبياهانا ...  2025/2/20  skynews
# 3     اتهمت حركة المقاومة الإسلامية (حماس) رئيس الوز...  2025/2/20  skynews
# 4     اتهم الرئيس البرازيليلولا دا سيلفانظيره الأمير...  2025/2/20  skynews
# ...                                                 ...        ...      ...
# 9985  انتقدت هيئة عائلات الأسرى الإسرائيليين المحتجز...  2025/1/25  skynews
# 9986  أعلنت وزارة الصحة الفلسطينية استشهاد شاب برصاص...  2025/1/29  skynews
# 9987                                                      2020/2/4  skynews
# 9988  في وقت يعقد فيه رئيس الوزراء الإسرائيليبنيامين...   2025/2/4  skynews
# 9989  شولا لاوال-خسر حزب المؤتمر الوطني الأفريقي الح...   2024/6/2  skynews
#
# [9990 rows x 4 columns]

# %%
import pandas as pd
from pymongo.mongo_client import MongoClient

# MongoDB Atlas connection URI
uri = "mongodb+srv://team_member:projectSD_Media1@cluster0.m6cwo.mongodb.net/projectSD?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(uri)

# Select Database and Collection
db = client["projectSD"]  # Change to your database name
collection = db["aljazira"]  # Change to your collection name

# Load CSV into DataFrame
csv_file = "aljazira.csv"  # Replace with the actual CSV file path
df = pd.read_csv(csv_file)

# Convert DataFrame to Dictionary
data = df.to_dict(orient="records")

# Insert Data into MongoDB Atlas
if data:  # Check if data is not empty
    collection.insert_many(data)
    print("✅ CSV data successfully inserted into MongoDB Atlas!")
else:
    print("⚠️ CSV file is empty. No data inserted.")

# Close the connection (optional)
client.close()
# Out:
# ✅ CSV data successfully inserted into MongoDB Atlas!
