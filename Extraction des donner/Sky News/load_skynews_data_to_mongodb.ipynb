# %%
import os
import pandas as pd

# Chemin du dossier contenant les fichiers CSV
dossier_csv = "./"

# Liste pour stocker les DataFrames
dataframes = []

# Lire tous les fichiers CSV du dossier
for fichier in os.listdir(dossier_csv):
    if fichier.endswith(".csv"):
        chemin_fichier = os.path.join(dossier_csv, fichier)
        df = pd.read_csv(chemin_fichier)
        dataframes.append(df)

# Fusionner tous les DataFrames
df_fusionne = pd.concat(dataframes, ignore_index=True)

# Enregistrer le résultat dans un nouveau fichier CSV


print("Fusion terminée ! Fichier enregistré sous 'fichier_fusionne.csv'.")
# Out:
# Fusion terminée ! Fichier enregistré sous 'fichier_fusionne.csv'.

# %%
df_fusionne.duplicated().sum()
# Out:
# 7860

# %%
df_fusionne.shape
# Out:
# (24394, 7)

# %%
df_fusionne.drop_duplicates(inplace=True)
df_fusionne
# Out:
#                 source                                              title  \
# 0      Sky News Arabic  روبيو:لقاء ترامب وبوتين بعد التقدم باتجاه إنها...
# 1      Sky News Arabic  رسوم ترامب على الألومنيوم ستشمل 123 منتجا منها...
# 2      Sky News Arabic  إيران وإسرائيل.. تصعيد متزايد يهدد استقرار الم...
# 3      Sky News Arabic      بكين تقول إن "نافذة للسلام" تُفتح في أوكرانيا
# 4      Sky News Arabic  الأمم المتّحدة: تعافي اقتصاد سوريا قد يستغرق 5...
# ...                ...                                                ...
# 24373  Sky News Arabic    واشنطن تكثف جهودها لضمان التوصل إلى هدنة في غزة
# 24375  Sky News Arabic          ألمانيا تعتزم استئناف التعاون مع الأونروا
# 24376  Sky News Arabic  بعد تراجع شعبيته.. استراتيجية بايدن لاستعادة ا...
# 24387  Sky News Arabic      ماذا تعني تهديدات بن غفير وسموتريتش لنتنياهو؟
# 24392  Sky News Arabic  لابيد ينتقد بن غفير وسموتريتش لتهديدهما بالانس...
#
#                                              description  \
# ...

# %%
df_fusionne[df_fusionne['url'].str.startswith('https://www.skynewsarabia.com')]
# Out:
#                 source                                              title  \
# 0      Sky News Arabic  روبيو:لقاء ترامب وبوتين بعد التقدم باتجاه إنها...
# 2      Sky News Arabic  إيران وإسرائيل.. تصعيد متزايد يهدد استقرار الم...
# 3      Sky News Arabic      بكين تقول إن "نافذة للسلام" تُفتح في أوكرانيا
# 6      Sky News Arabic  سوق تاريخي في غزة يتحول إلى مكب للنفايات بعد ت...
# 10     Sky News Arabic  مستشار أميركي: إحباط ترامب من زيلينسكي "متعدد ...
# ...                ...                                                ...
# 24373  Sky News Arabic    واشنطن تكثف جهودها لضمان التوصل إلى هدنة في غزة
# 24375  Sky News Arabic          ألمانيا تعتزم استئناف التعاون مع الأونروا
# 24376  Sky News Arabic  بعد تراجع شعبيته.. استراتيجية بايدن لاستعادة ا...
# 24387  Sky News Arabic      ماذا تعني تهديدات بن غفير وسموتريتش لنتنياهو؟
# 24392  Sky News Arabic  لابيد ينتقد بن غفير وسموتريتش لتهديدهما بالانس...
#
#                                              description  \
# ...

# %%
df_fusionne.to_csv('skynews_full_data.csv')

# %%
import pandas as pd
from pymongo.mongo_client import MongoClient

# MongoDB Atlas connection URI
uri = "mongodb+srv://team_member:projectSD_Media1@cluster0.m6cwo.mongodb.net/projectSD?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(uri)

# Select Database and Collection
db = client["projectSD"]  # Change to your database name
collection = db["skynews"]  # Change to your collection name

# Load CSV into DataFrame
csv_file = "skynews_full_data.csv"  # Replace with the actual CSV file path
df = pd.read_csv(csv_file)

# Convert DataFrame to Dictionary
data = df.to_dict(orient="records")

# Insert Data into MongoDB Atlas
if data:  # Check if data is not empty
    collection.insert_many(data)
    print("✅ CSV data successfully inserted into MongoDB Atlas!")
else:
    print("⚠️ CSV file is empty. No data inserted.")

# Close the connection (optional)
client.close()
# Out:
# ✅ CSV data successfully inserted into MongoDB Atlas!
