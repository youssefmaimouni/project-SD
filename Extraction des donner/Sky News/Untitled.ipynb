# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("skynews_full_data.csv")  # Replace with your actual file name

# Count occurrences and convert to dictionary
tag_counts = df["tags"].value_counts().to_dict()


tag_counts
# Out:
# {"['أخبار إسرائيل']": 4197,
#  "['أخبار أميركا']": 1828,
#  "['أخبار فلسطين']": 1775,
#  '[]': 1151,
#  "['أخبار لبنان']": 925,
#  "['شرق أوسط']": 909,
#  "['أخبار إيران']": 412,
#  "['أخبار العالم']": 351,
#  "['أخبار سوريا']": 339,
#  "['اقتصاد']": 334,
#  "['أزمة أوكرانيا']": 299,
#  "['نفط']": 285,
#  "['ذهب']": 264,
#  "['أخبار روسيا']": 216,
#  "['أسواق عالمية']": 210,
#  "['أسواق']": 191,
#  "['أخبار اليمن']": 177,
#  "['أخبار الشركات']": 177,
#  "['أخبار مصر']": 165,
#  "['منوعات']": 141,
#  "['عملات']": 141,
#  "['Businessمع لبنى']": 118,
#  "['تكنولوجيا']": 103,
#  "['اقتصاد عالمي']": 99,
#  "['دونالد ترامب']": 98,
#  "['انتخابات أميركا']": 92,
#  "['طاقة']": 91,
#  "['أخبار الصين']": 84,
#  "['حوادث وكوارث']": 78,
#  "['أخبار الإمارات']": 70,
#  "['أخبار العراق']": 69,
#  "['أخبار تركيا']": 57,
#  "['أخبار الأردن']": 57,
#  "['صحة']": 50,
#  "['أخبار السعودية']": 50,
#  "['اتحاد أوروبي']": 48,
#  "['أخبار علمية']": 45,
#  "['أخبار فرنسا']": 44,
#  "['أخبار السودان']": 44,
# ...

# %%
df.shape
# Out:
# (16534, 8)
