# %%
import pandas as pd 

chemin_fichiers=['./Extraction des donner/France24/france_24_clened_data.csv','./Extraction des donner/Sky News/skynews_data_cleaned_vf.csv']
dataframes = []

for chemin_fichier in chemin_fichiers :
    df = pd.read_csv(chemin_fichier)
    dataframes.append(df)

df_fusionne = pd.concat(dataframes, ignore_index=True)
df_fusionne
# Out:
#                 source  ...                                            content
# 0            France_24  ...  تغلبت الملاكمة الجزائرية إيمان خليف على خصمتها...
# 1            France_24  ...  موفد فرانس24 إلى سان دوني – تتواصل فعاليات معر...
# 2            France_24  ...  تظاهر آلاف الأشخاص في تركيا والمغرب وتونس تندي...
# 3            France_24  ...  دانت قناة الجزيرة القطرية الأربعاء "اغتيال" اث...
# 4            France_24  ...  خليل الحية القيادي في حماس: الحركة وإيران لا ت...
# ...                ...  ...                                                ...
# 26739  Sky_News_Arabic  ...  كثفت واشنطن مبادراتها، يوم الجمعة، سعيا لضمان ...
# 26740  Sky_News_Arabic  ...  قالت وزارتا الخارجية والتنمية الألمانيتان في ب...
# 26741  Sky_News_Arabic  ...  سيكشف الرئيس الأميركي جو بايدن عن استراتيجيته ...
# 26742  Sky_News_Arabic  ...  شدد وزير المالية الإسرائيلي بتسلئيل سموتريش وو...
# 26743  Sky_News_Arabic  ...  انتقد زعيم المعارضة في إسرائيل يائير لابيد، ال...
#
# [26744 rows x 6 columns]

# %%
df_fusionne.to_csv("full_data_fusionne.csv", index=False)
